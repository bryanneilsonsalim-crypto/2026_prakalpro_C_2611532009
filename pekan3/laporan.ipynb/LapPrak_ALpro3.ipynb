# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **Algoritma dan Pemrograman**
#
# **“Operator”**
#
# **Disusun Oleh :**
#
# **Bryan Neilson Salim**
#
# **2611532009**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="image/logounand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum algoritma dan pemrograman yang telah dilaksanakan sebagai pertemuan ke-2 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan Operator berupa aritmatika, assignment, bitwise, logika, perbandingan, dan lainnya
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dan manfaat mempelajari operator aritmatika seperti aritmatika, assignment, bitwise, logika, perbandingan, dan lainnya
#
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
# <br>
# <br>
# <br>
# <br>
# Bryan Neilson Salim,<br>2611532009

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Algoritma dan pemrograman merupakan mata kuliah dasar yang menjadi fondasi bagi mahasiswa program studi ilmu komputer maupun sistem informasi dalam membangun kemampuan berpikir logis dan sistematis sebelum masuk ke materi-materi yang lebih kompleks. Salah satu konsep fundamental yang dipelajari pada tahap awal mata kuliah ini adalah operator, yaitu simbol yang digunakan oleh compiler atau interpreter untuk melakukan operasi tertentu, seperti operasi matematika, rasional, atau logis, agar dapat menghasilkan hasil akhir sesuai yang diinginkan. Operator dapat dikatakan sebagai dasar dari sebuah bahasa pemrograman jenis apapun, sebab hampir seluruh proses pengolahan data dalam suatu program — mulai dari perhitungan, pengambilan keputusan, hingga manipulasi data pada level bit  membutuhkan peran operator sebagai simbol penghubung antar-operand.
#
# Secara umum, operator dalam bahasa pemrograman Python dikelompokkan ke dalam beberapa jenis, yaitu operator aritmatika, operator perbandingan (relasi), operator logika, operator penugasan (assignment), operator bitwise, serta beberapa operator tambahan seperti operator identitas dan operator keanggotaan. Operator aritmatika digunakan untuk melakukan operasi matematis dasar seperti penjumlahan, pengurangan, perkalian, pembagian, pembagian bulat, modulus, dan pemangkatan. Operator perbandingan digunakan untuk membandingkan dua buah nilai dan menghasilkan keluaran berupa nilai boolean, benar (True) atau salah (False). Operator logika digunakan untuk menguji atau menggabungkan satu maupun lebih ekspresi logika menggunakan and, or, dan not. Operator penugasan digunakan untuk memberikan atau memperbarui nilai suatu variabel secara langsung maupun secara ringkas melalui operator gabungan seperti +=, -=, dan sejenisnya. Sementara itu, operator bitwise digunakan untuk memanipulasi bit-bit dari nilai data yang tersimpan di dalam memori, seperti AND, OR, NOT, XOR, serta pergeseran bit ke kiri maupun ke kanan (Modul Pembelajaran Algoritma Pemrograman, Universitas Tanjungpura, 2020: hlm. 20).
#
# Meskipun konsep operator tampak sederhana pada tataran teori, dalam praktiknya mahasiswa pemula masih sering mengalami kesulitan dalam memahami konsep dasar pemrograman seperti variabel, operator, maupun logika program apabila hanya diajarkan secara satu arah tanpa disertai praktik langsung . Kesulitan ini dapat menghambat proses pembelajaran, menurunkan motivasi, serta memengaruhi kemampuan problem-solving mahasiswa dalam mata kuliah dasar-dasar pemrograman . Kesalahan yang umum ditemui antara lain tertukarnya operator penugasan (=) dengan operator perbandingan (==), kekeliruan hasil antara pembagian biasa (/) dan pembagian bulat (//), kebingungan terhadap urutan pengerjaan operator (operator precedence) ketika beberapa operator digabungkan dalam satu ekspresi, hingga kesulitan memahami logika operator bitwise yang mengharuskan mahasiswa berpikir dalam representasi biner suatu bilangan.
#
# Untuk mengatasi permasalahan tersebut, interaksi antara mahasiswa dan fasilitator selama pembelajaran praktik dalam mata kuliah dasar-dasar pemrograman memiliki peran penting dalam membentuk pemahaman konsep dan keterampilan teknis mahasiswa . Pendekatan pembelajaran berbasis praktik dan pelatihan langsung juga terbukti efektif dalam meningkatkan pemahaman konsep, keterampilan pemecahan masalah, dan kemampuan kolaborasi mahasiswa dalam mempelajari bahasa pemrograman . Selain interaksi dengan fasilitator, ketersediaan sarana belajar yang memadai juga terbukti memiliki pengaruh yang signifikan terhadap hasil belajar pemrograman mahasiswa, dengan nilai kontribusi sebesar 56,7% terhadap peningkatan hasil belajar. Temuan-temuan ini menegaskan bahwa pemahaman konsep dasar pemrograman, termasuk operator, tidak cukup hanya disampaikan secara teoritis, melainkan harus didukung oleh kegiatan praktikum yang terstruktur serta sarana pendukung pembelajaran yang memadai.
#
# Atas dasar pertimbangan tersebut, disusunlah laporan praktikum mengenai operator dalam algoritma dan pemrograman ini, yang mencakup operator aritmatika, operator perbandingan, operator logika, operator penugasan (assignment), operator bitwise, serta operator-operator lainnya. Melalui kegiatan praktikum ini, mahasiswa diharapkan tidak hanya mampu menghafal simbol dan tabel operator, tetapi juga memahami secara konseptual bagaimana setiap operator bekerja, kapan operator tersebut tepat digunakan, serta bagaimana kombinasi antar-operator dapat diterapkan untuk menyelesaikan suatu permasalahan dalam bentuk program. Pemahaman yang kuat terhadap materi operator ini akan menjadi fondasi penting bagi mahasiswa sebelum melangkah ke materi lanjutan seperti struktur kontrol percabangan, perulangan (looping), fungsi, dan struktur data pada tahapan pembelajaran algoritma dan pemrograman berikutnya.
#
#
# ## 1.2 Tujuan
# 1. Mahasiswa mampu menjelaskan pengertian dan fungsi berbagai jenis operator dalam bahasa pemrograman Python, meliputi operator aritmatika, perbandingan, logika, penugasan (assignment), bitwise, serta operator lainnya.
# 2. Mahasiswa mampu mengimplementasikan setiap jenis operator tersebut ke dalam kode program Python secara benar sesuai kaidah penulisan (syntax) dan urutan pengerjaan (precedence) yang berlaku.
# 3. Mahasiswa mampu menganalisis dan menerapkan kombinasi berbagai operator untuk menyelesaikan studi kasus atau permasalahan sederhana dalam bentuk program.
# ## 1.3 Manfaat
# 1. Bagi Pelajar: Memperkuat pemahaman konsep dasar pemrograman melalui praktik langsung, sehingga menjadi bekal yang kokoh untuk mempelajari materi lanjutan seperti struktur kontrol, perulangan, fungsi, dan struktur data.
# 2. Bagi pengajar/Dosen: Sebagai alat evaluasi untuk mengukur sejauh mana mahasiswa memahami dan mampu mengimplementasikan konsep operator, sehingga dapat menjadi dasar dalam menentukan strategi pengajaran pada materi lanjutan.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Berikut ini merupakan penjelasan mengenai dasar teori yang digunakan untuk praktikum ini :
#
# 1. Operator Aritmatika: adalah operator yang digunakan untuk melakukan operasi matematis terhadap dua buah operand atau lebih. Dalam bahasa Python, operator aritmatika terdiri atas:
#
# - Operator + (Penjumlahan): Menjumlahkan dua operand, contoh x + y
# - Operator - (Pengurangan): Mengurangkan dua operand, contoh x - y
# - Operator * (Perkalian): Mengalikan dua operand, contoh x * y
# - Operator / (Pembagian): Membagi dua operand (hasil desimal), contoh x / y
# - Operator // (Pembagian bulat): Membagi dan membulatkan ke bawah, contoh x // y
# - Operator % (Modulus): Menghasilkan sisa pembagian, contoh x % y
# - Operator ** (Pemangkatan): Memangkatkan suatu bilangan, contoh x ** y
#
# 2. Operator Perbandingan (Relasi): digunakan untuk membandingkan hubungan antara dua buah operand dan menghasilkan nilai boolean, yaitu True atau False . Operator ini umumnya digunakan sebagai kondisi dalam struktur percabangan maupun perulangan. Jenis-jenisnya meliputi:  **== (sama dengan)**, **!= (tidak sama dengan)**, **> (lebih besar)**, **< (lebih kecil)**,  **>= (lebih besar atau sama dengan)**, dan **<= (lebih kecil atau sama dengan)**.
#
# 3. Operator logika digunakan untuk menggabungkan atau menguji satu maupun lebih ekspresi kondisi (perbandingan) sehingga menghasilkan satu nilai kebenaran akhir. Terdapat tiga operator logika dalam Python, yaitu **and (bernilai True jika kedua kondisi benar)**, **or (bernilai True jika salah satu kondisi benar)**, **not (membalikkan nilai kebenaran suatu kondisi)**, dan **XOR (bernilai benar hanya jika nilai input atau kondisinya berbeda)**.
#
# 4. Operator penugasan digunakan untuk memberikan atau memperbarui nilai ke dalam suatu variabel. Selain operator = sebagai penugasan dasar, Python juga menyediakan operator penugasan gabungan (compound assignment) yang menggabungkan operasi aritmatika/bitwise dengan penugasan, seperti `+=, -=, *=, /=, //=, %=, **=, &=, |=, ^=, >>=, dan <<=,` yang berfungsi mempersingkat penulisan ekspresi (misalnya x += 5 setara dengan x = x + 5).
#
# 5. Operator bitwise digunakan untuk memanipulasi bit-bit dari nilai data yang tersimpan di dalam memori. Operator ini bekerja pada representasi biner suatu bilangan bulat. Jenis-jenisnya meliputi **& (AND), | (OR), ~ (NOT), ^ (XOR), >> (pergeseran bit ke kanan), dan << (pergeseran bit ke kiri)**.
#
# 6. Selain kelima jenis operator di atas, Python juga menyediakan operator identitas, yaitu ** is dan is not**, yang digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama di memori; serta operator keanggotaan, yaitu **in dan not in**, yang digunakan untuk memeriksa apakah suatu nilai terdapat di dalam sebuah struktur data seperti list, tuple, atau string.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Operator Aritmatika "aritmatika_2611532009"
# Berikut ini merupakan program aritmatika yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama aritmatika_NIM.py
# Buat program untuk operator aritmatika dalam Python
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menngunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_2009 = int(input("Input angka-1: "))
angka2_2009 = int(input("Input angka-2: "))

# Penjumlahan
hasil_2009 = angka1_2009 + angka2_2009
print("\nOperator Penjumlahan")
print("Hasil =",hasil_2009)

# Pengurangan
hasil_2009 = angka1_2009 - angka2_2009
print("\nOperator Pengurangan")
print("Hasil =",hasil_2009)

# Perkalian
hasil_2009 = angka1_2009 * angka2_2009
print("\nOperator Perkalian")
print("Hasil =",hasil_2009)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_2009 != 0:
    hasil_2009 = angka1_2009 / angka2_2009
    print("\nOperator Pembagian")
    print("Hasil =",hasil_2009)
    hasil_2009 = angka1_2009 // angka2_2009
    print("\nOperator Pembagian Bulat")
    print("Hasil =",hasil_2009)
    hasil_2009 = angka1_2009 % angka2_2009
    print("\nOperator Sisa Bagi")
    print("Hasil =",hasil_2009)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil_2009 = angka1_2009 ** angka2_2009
print("\nOperator Pangkat")
print("Hasil =",hasil_2009)

# %% [markdown]
# **Penjelasan :**
# 1. ***angka1_2009 = int(input("Input angka-1: "))*** — Meminta input angka pertama dari pengguna, langsung dikonversi ke tipe data int agar bisa dioperasikan secara matematis.
# 2. ***angka2_2009 = int(input("Input angka-2: "))*** — Meminta input angka kedua dari pengguna, juga dikonversi ke int.
# 3. ***hasil_2009 = angka1_2009 + angka2_2009*** — Menerapkan operator penjumlahan (+): menjumlahkan angka1_2009 dan angka2_2009.
# 4. ***print("\nOperator Penjumlahan") dan print("Hasil =",hasil_2009)*** — Mencetak label operasi beserta hasil penjumlahannya.
# 5. ***hasil_2009 = angka1_2009 - angka2_2009*** — Menerapkan operator pengurangan (-): mengurangkan angka2_2009 dari angka1_2009.
# 6. ***print(...) (2 baris)*** — Mencetak label "Operator Pengurangan" beserta hasilnya.
# 7. ***hasil_2009 = angka1_2009 * angka2_2009*** — Menerapkan operator perkalian (*): mengalikan kedua angka.
# 8. ***print(...) (2 baris)*** — Mencetak label "Operator Perkalian" beserta hasilnya.
# 9. ***if angka2_2009 != 0:*** — Pengecekan kondisi untuk mencegah error pembagian dengan nol (ZeroDivisionError) sebelum menjalankan tiga jenis operasi pembagian di bawahnya.
# 10. ***hasil_2009 = angka1_2009 / angka2_2009*** — Menerapkan operator pembagian (/): hasilnya berupa bilangan desimal (float).
# 11. ***print(...) (2 baris)*** — Mencetak label "Operator Pembagian" beserta hasilnya.
# 12. ***hasil_2009 = angka1_2009 // angka2_2009*** — Menerapkan operator pembagian bulat (//): hasil pembagian dibulatkan ke bawah (floor division).
# 13. ***print(...) (2 baris)*** — Mencetak label "Operator Pembagian Bulat" beserta hasilnya.
# 14. ***hasil_2009 = angka1_2009 % angka2_2009*** — Menerapkan operator sisa bagi/modulus (%): menghasilkan sisa dari pembagian angka1_2009 oleh angka2_2009.
# 15. ***print(...) (2 baris)*** — Mencetak label "Operator Sisa Bagi" beserta hasilnya.
# 16. ***else: beserta print("Angka kedua tidak boleh bernilai 0.")*** — Jika angka2_2009 bernilai 0, program tidak menjalankan operasi pembagian sama sekali dan hanya mencetak pesan peringatan, sehingga terhindar dari crash program.
# 17. ***hasil_2009 = angka1_2009 ** angka2_2009*** — Menerapkan operator pemangkatan (**): memangkatkan angka1_2009 sebanyak angka2_2009. Operasi ini diletakkan di luar blok if/else karena pemangkatan tidak berisiko error meski angka2_2009 bernilai 0 (hasil pangkat 0 selalu 1).
# 18. ***print("\nOperator Pangkat") dan print("Hasil =",hasil_2009)*** — Mencetak label operasi beserta hasil pemangkatannya.

# %% [markdown]
# **Berikut ini adalah Output dari Program Operator Aritmatika yang dijalankan menggunanakan terminal:**
#
# <div align="center">
# <img src="image/output_aritmatika.png" width="500"><br>
# <em>Gambar 2.1 : Output Aritmatika</em>
# </div>

# %% [markdown]
# ### 2.2.2 Program Operator Logika "logika_2611532009"
# Berikut ini merupakan program logika yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama logika_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: a1_1234
# Program ini menngunakan fungsi input()
# Program operator logika dalam Python

# Memasukan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_2009 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
a2_2009 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"

print("\nA1 = ",a1_2009)
print("A2 = ",a2_2009)

# Konjungsi: bernilai True jika keduanya True
hasil_2009 = a1_2009 and a2_2009
print("\nKonjungsi (AND)")
print("A1 and A2 =",hasil_2009)

# Disjungsi: bernilai True jika salah satunya False
hasil_2009 = a1_2009 or a2_2009
print("\nDisjungsi (OR)")
print("A1 or A2 =",hasil_2009)

# Negasi A1: membalik nilai A1
hasil_2009 = not a1_2009
print("\nNegasi A1(NOT)")
print("not A1",hasil_2009)

# Negasi A2: membalik nilai A2
hasil_2009 = not a2_2009
print("\nNegasi A2(NOT)")
print("not A2",hasil_2009)

# XOR: bernilai True jika kedua nilai berbeda
hasil_2009 = a1_2009 != a2_2009
print("\nDisjungsi Ekslusif (XOR)")
print("A1 XOR A2",hasil_2009)

# %% [markdown]
# **Penjelasan:**
# 1. ***a1_2009 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"*** — Meminta input teks dari pengguna, menghapus spasi di awal/akhir (.strip()), mengubah semua huruf jadi kecil (.lower()), lalu membandingkannya dengan string "true". Hasil perbandingan (True/False) langsung disimpan sebagai nilai boolean ke a1_2009. Karena diubah ke huruf kecil dulu, input seperti "TRUE", "True", atau "true" semuanya dikenali sama.
# 2. ***a2_2009 = input(...).strip().lower() == "true"*** — Pola yang sama untuk mengambil nilai boolean kedua ke a2_2009.
# 3. ***print("\nA1 = ",a1_2009) dan print("A2 = ",a2_2009)*** — Menampilkan nilai boolean yang sudah tersimpan di a1_2009 dan a2_2009 sebagai referensi awal.
# 4. ***hasil_2009 = a1_2009 and a2_2009*** — Menerapkan operator logika and (konjungsi): bernilai True hanya jika kedua nilai (a1_2009 dan a2_2009) bernilai True.
# 5. ***print("\nKonjungsi (AND)") dan print("A1 and A2 =",hasil_2009)*** — Mencetak label dan hasil operasi AND.
# 6. ***hasil_2009 = a1_2009 or a2_2009*** — Menerapkan operator logika or (disjungsi): bernilai True jika salah satu atau kedua nilai bernilai True. Hasilnya disimpan ke variabel hasil_2009.
# 7. ***print("\nDisjungsi (OR)") dan print("A1 or A2 =",hasil_2009)*** — Mencetak label "Disjungsi (OR)", tetapi nilai yang dicetak adalah hasil_2009, bukan hasil_1021 tempat hasil OR disimpan.
# 8. ***hasil_2009 = not a1_2009*** — Menerapkan operator logika not (negasi): membalik nilai boolean a1_2009 (jika True jadi False, dan sebaliknya).
# 9. ***print("\nNegasi A1(NOT)") dan print("not A1",hasil_2009)*** — Mencetak label dan hasil negasi a1_2009.
# 10. ***hasil_2009 = not a2_2009*** — Menerapkan operator not untuk membalik nilai boolean a2_2009.
# 11. ***print("\nNegasi A2(NOT)") dan print("not A2",hasil_2009)*** — Mencetak label dan hasil negasi a2_2009.
# 12. ***hasil_2009 = a1_2009 != a2_2009*** — Mensimulasikan operator XOR (disjungsi eksklusif) menggunakan !=, karena Python tidak memiliki operator XOR bawaan untuk boolean. Bernilai True jika kedua nilai berbeda (satu True dan satu False).
# 13. ***print("\nDisjungsi Ekslusif (XOR)") dan print("A1 XOR A2",hasil_2009)*** — Mencetak label dan hasil operasi XOR.

# %% [markdown]
# **Berikut ini adalah Output dari Program Operator logika yang dijalankan menggunanakan terminal:**
#
# <div align="center">
# <img src="image/output_logika.png" width="500"><br>
# <em>Gambar 2.2 : Output Logika</em>
# </div>

# %% [markdown]
# ### 2.2.3 Program Perbandingan "perbandingan_2611532009"
# Berikut ini merupakan program Perbandingan yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menngunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_2009 = int(input("Input angka-1: "))
angka2_2009 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_2009 = angka1_2009 > angka2_2009
print("\nOperator lebih besar dari")
print("angka1 > angka2 =",hasil_2009)

# Lebih kecil dari
hasil_2009 = angka1_2009 < angka2_2009
print("\nOperator lebih kecil dari")
print("angka1 < angka2 =",hasil_2009)

# Lebih besar dari atau sama dengan
hasil_2009 = angka1_2009 >= angka2_2009
print("\nOperator lebih besar dari atau sama dengan")
print("angka1 >= angka2 =",hasil_2009)

# Lebih kecil dari atau sama dengan
hasil_2009 = angka1_2009 <= angka2_2009
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =",hasil_2009)

# Sama dengan
hasil_2009 = angka1_2009 == angka2_2009
print("\nOperator sama dengan")
print("angka1 == angka2 =",hasil_2009)

# Tidak sama dengan
hasil_2009 = angka1_2009 != angka2_2009
print("\nOperator tidak sama dengan")
print("angka1 != angka2 =",hasil_2009)

# Tambahan: perbandingan berantai dalam Python
hasil_2009 = 0 < angka1_2009 < 100
print("\nPerbandingan berantai")
print("0 < angka1_2009 < 100 =",hasil_2009)

hasil_2009 = 0 < angka2_2009 < 100
print("0 < angka2_2009 < 100 =",hasil_2009)

# %% [markdown]
# **Penjelasan:**
# 1. ***angka1_2009 = int(input("Input angka-1: "))*** — Meminta input angka pertama dari pengguna, dikonversi ke tipe int.
# 2. ***angka2_2009 = int(input("Input angka-2: "))*** — Meminta input angka kedua dari pengguna, dikonversi ke tipe int.
# 3. ***hasil_2009 = angka1_2009 > angka2_2009*** — Menerapkan operator lebih besar dari (>): bernilai True jika angka1_2009 lebih besar dari angka2_2009.
# 4. ***print("\nOperator lebih besar dari") dan print("angka1 > angka2 =",hasil_2009)*** — Mencetak label operasi beserta hasil perbandingannya.
# 5. ***hasil_2009 = angka1_2009 < angka2_2009*** — Menerapkan operator lebih kecil dari (<): bernilai True jika angka1_2009 lebih kecil dari angka2_2009.
# 6. ***print(...) (2 baris)*** — Mencetak label dan hasil operator <.
# 7. ***hasil_2009 = angka1_2009 >= angka2_2009*** — Menerapkan operator lebih besar dari atau sama dengan (>=).
# 8. ***print(...) (2 baris)*** — Mencetak label dan hasil operator >=.
# 9. ***hasil_2009 = angka1_2009 <= angka2_2009*** <= angka2_2009 — Menerapkan operator lebih kecil dari atau sama dengan (<=).
# 10. ***print(...) (2 baris)*** — Mencetak label dan hasil operator <=.
# 11. ***hasil_2009 = angka1_2009 == angka2_2009*** — Menerapkan operator sama dengan (==): bernilai True jika kedua nilai identik.
# 12. ***print(...) (2 baris)*** — Mencetak label dan hasil operator ==.
# 13. ***hasil_2009 = angka1_2009 != angka2_2009*** — Menerapkan operator tidak sama dengan (!=): bernilai True jika kedua nilai berbeda.
# 14. ***print(...) (2 baris)*** — Mencetak label dan hasil operator !=.
# 15. ***hasil_2009 = 0 < angka1_2009*** < 100 — Menerapkan fitur perbandingan berantai (chained comparison): setara dengan (0 < angka1_2009) and (angka1_2009 < 100), mengecek apakah  angka1_2009 berada dalam rentang 0–100 dalam satu ekspresi.
# 16. ***print("\nPerbandingan berantai") dan print("0 < angka1_2009 < 100 =",hasil_2009)*** — Mencetak label dan hasil perbandingan berantai untuk angka1_2009.
# hasil_2009 = 0 < angka2_2009 < 100 — Menerapkan perbandingan berantai yang sama, kali ini untuk angka2_2009.
# 17. ***print("0 < angka2_2009 < 100 =",hasil_2009)*** — Mencetak hasil perbandingan berantai untuk angka2_2009.

# %% [markdown]
# **Berikut ini adalah Output dari Program Operator Perbandingan yang dijalankan menggunanakan terminal:**
#
# <div align="center">
# <img src="image/output_perbandingan.png" width="500"><br>
# <em>Gambar 2.3 : Output Perbandingan </em>
# </div>

# %% [markdown]
# ### 2.2.4 Program Operator Bitwise "bitwise_2611532009"
# Berikut ini merupakan program bitwise yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("======================================")
print("3. OPERATOR BITWISE")
print("======================================")

angka1_2009 = int(input("Masukkan angka bitwise-1: "))
angka2_2009 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =",angka1_2009,"| biner =",bin(angka1_2009))
print("angka2 =",angka2_2009,"| biner =",bin(angka2_2009))

# Bitwise AND
hasil_2009 = angka1_2009 & angka2_2009
print("\nBitwise AND (&)")
print(angka1_2009,"&",angka2_2009,hasil_2009)
print("Biner hasil =",bin(hasil_2009))
print("Biner hasil (8 bit) =",format(hasil_2009,"08b"))

# Bitwise OR
hasil_2009 = angka1_2009 | angka2_2009
print("\nBitwise OR (|)")
print(angka1_2009,"|",angka2_2009,hasil_2009)
print("Biner hasil =",bin(hasil_2009))
print("Biner hasil (8 bit) =",format(hasil_2009,"08b"))

# Bitwise XOR
hasil_2009 = angka1_2009 ^ angka2_2009
print("\nBitwise XOR (^)")
print(angka1_2009,"^",angka2_2009,hasil_2009)
print("Biner hasil =",bin(hasil_2009))
print("Biner hasil (8 bit) =",format(hasil_2009,"08b"))

# Bitwise NOT
hasil_2009 = ~angka1_2009
print("\nBitwise NOT (~)")
print("~", angka1_2009, "=", hasil_2009)
print("Biner hasil =",bin(hasil_2009))
print("Biner hasil (8 bit) =",format(hasil_2009,"08b"))

# Bitwise geser kiri
jumlah_geser_2009 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_2009 = angka1_2009 << jumlah_geser_2009
print("\nBitwise geser kiri (<<)")
print(angka1_2009,"<<",jumlah_geser_2009,"=",hasil_2009)
print("Biner hasil =",bin(hasil_2009))
print("Biner hasil (8 bit) =",format(hasil_2009,"08b"))

# Bitwise geser kanan
hasil_2009 = angka1_2009 >> jumlah_geser_2009
print("\nBitwise geser kanan (>>)")
print(angka1_2009,">>",jumlah_geser_2009,"=",hasil_2009)
print("Biner hasil =",bin(hasil_2009))
print("Biner hasil (8 bit) =",format(hasil_2009,"08b"))

# %% [markdown]
# **Penjelasan:**
# 1. ***print("=====...") (3 baris)*** — Mencetak garis pembatas dan judul "3. OPERATOR BITWISE" sebagai header visual program.
# 2. ***angka1_2009 = int(input("Masukkan angka bitwise-1: "))*** — Meminta input angka pertama dari pengguna, dikonversi ke tipe int karena operator bitwise hanya berlaku pada bilangan bulat.
# 3. ***angka2_2009 = int(input("Masukkan angka bitwise-2: "))*** — Meminta input angka kedua dari pengguna, juga dikonversi ke int.
# 4. ***print("\nAngka dalam bentuk desimal dan biner")*** — Header untuk bagian yang menampilkan representasi biner kedua angka.
# 5. ***print("angka1 =",angka1_2009,"| biner =",bin(angka1_2009))*** — Menampilkan angka1_2009 dalam bentuk desimal dan biner menggunakan fungsi bin(), yang mengonversi integer ke format string biner berawalan 0b.
# 6. ***print("angka2 =",angka2_2009,"| biner =",bin(angka2_2009))*** — Menampilkan angka2_2009 dalam bentuk desimal dan biner.
# 7. ***hasil_2009 = angka1_2009 & angka2_2009*** — Menerapkan operator Bitwise AND (&): membandingkan tiap bit kedua angka, hasil bit bernilai 1 hanya jika kedua bit sama-sama 1.
# 8. ***print(...) (4 baris setelahnya)*** — Mencetak label operasi, ekspresi beserta hasil desimalnya, hasil dalam biner (bin()), dan hasil biner dengan format 8-digit menggunakan format(hasil_2009,"08b") agar lebih rapi dibaca (padding nol di depan).
# 9. ***hasil_2009 = angka1_2009 | angka2_2009*** — Menerapkan operator Bitwise OR (|): hasil bit bernilai 1 jika salah satu atau kedua bit bernilai 1.
# 10. ***print(...) (4 baris setelahnya)*** — Pola cetak yang sama seperti AND: ekspresi & hasil desimal, hasil biner, dan hasil biner 8-bit.
# 11. ***hasil_2009 = angka1_2009 ^ angka2_2009*** — Menerapkan operator Bitwise XOR (^): hasil bit bernilai 1 hanya jika kedua bit berbeda.
# 12. ***print(...) (4 baris setelahnya)*** — Pola cetak yang sama untuk hasil XOR.
# 13. ***hasil_2009 = ~angka1_2009*** — Menerapkan operator Bitwise NOT (~): membalik seluruh bit angka1_2009 (secara matematis setara dengan -angka1_2009 - 1 pada representasi two's complement).
# 14. ***print("~", angka1_2009, "=", hasil_2009)***— Mencetak ekspresi beserta hasil NOT.
# 15. ***print("Biner hasil =",bin(hasil_2009))*** ***dan print("Biner hasil (8 bit) =",...***) — Menampilkan hasil NOT dalam bentuk biner. Karena hasil NOT pada bilangan positif akan bernilai negatif, bin() akan menampilkan tanda minus (-0b...), dan format(...,"08b") pada bilangan negatif juga akan tetap menampilkan tanda minus di depan digit binernya (bukan direpresentasikan sebagai bit 2's complement 8-bit yang sesungguhnya).
# 16.*** jumlah_geser_2009 = int(input("\nMasukkan jumlah pergeseran bit: "))*** — Meminta input jumlah posisi pergeseran bit yang akan digunakan untuk operasi geser kiri dan kanan berikutnya.
# 17. ***hasil_2009 = angka1_2009 << jumlah_geser_2009*** — Menerapkan operator Bitwise geser kiri (<<): menggeser seluruh bit angka1_2009 ke kiri sebanyak jumlah_geser_2009 posisi (efeknya sama dengan mengalikan angka1_2009 dengan 2 pangkat jumlah_geser_2009).
# 18. ***print(...) (4 baris setelahnya)*** — Mencetak label "Bitwise geser kiri (<<)", ekspresi beserta hasilnya, hasil biner, dan hasil biner 8-bit.
# 19. ***hasil_2009 = angka1_2009 >> jumlah_geser_2009*** — Menerapkan operator Bitwise geser kanan (>>): menggeser seluruh bit angka1_2009 ke kanan sebanyak jumlah_geser_2009 posisi (efeknya sama dengan pembagian bulat angka1_2009 dengan 2 pangkat jumlah_geser_2009).
# 20. ***print("\nBitwise geser kiri (>>)")*** — Mencetak label untuk operasi geser kanan.
# 21. ***print(...) (3 baris setelahnya)*** — Mencetak ekspresi beserta hasil geser kanan, hasil biner, dan hasil biner 8-bit.

# %% [markdown]
# **Berikut ini adalah Output dari Program Operator Bitwise yang dijalankan menggunanakan terminal:**
#
# <div align="center">
# <img src="image/output_bitwise.png" width="500"><br>
# <em>Gambar 2.4 : Output Bitwise</em>
# </div>

# %% [markdown]
# ### 2.2.5 Program Operator Assignment "assignment_2611532009"
# Berikut ini merupakan program assignment yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama assigment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menngunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assigment dalam Python

angka1_2009 = int(input("Input angka-1: "))
angka2_2009 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =",angka1_2009)
print("Nilai angka2 =",angka2_2009)

# Assigment biasa
hasil_2009 = angka1_2009 
print("\nAssigment biasa (=)")
print("Hasil =",hasil_2009)

# Assigment penambahan
hasil_2009 = angka1_2009 
hasil_2009 += angka2_2009
print("\nAssigment penambahan (+=)")
print("Hasil =",hasil_2009)

# Assigment pengurangan
hasil_2009= angka1_2009 
hasil_2009 -= angka2_2009 
print("\nAssigment pengurangan (-=)")
print("Hasil =",hasil_2009)

# Assigment perkalian
hasil_2009 = angka1_2009 
hasil_2009 *= angka2_2009
print("\nAssigment perkalian (*=)")
print("Hasil =",hasil_2009)

# Assigment pembagian, pembagian bulat, dan sisa bagi
if angka2_2009 != 0:
    hasil_2009 = angka1_2009
    hasil_2009/= angka2_2009
    print("\nAssigment pembagian (/=)")
    print("Hasil =",hasil_2009)
    # Operator tambahan
    hasil_2009 = angka1_2009 
    hasil_2009 //= angka2_2009
    print("\nAssigment pembagian bulat (//=)")
    print("Hasil =",hasil_2009)
    hasil_2009 = angka1_2009 
    hasil_2009 %= angka2_2009
    print("\nOperator sisa bagi (%=)")
    print("Hasil =",hasil_2009)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assigment perpangkatan
hasil_2009 = angka1_2009 
hasil_2009 **= angka2_2009
print("\nOperator perpangkatan (**=)")
print("Hasil =",hasil_2009)

# %% [markdown]
# **Penjelasan:**
# 1. ***angka1_2009 = int(input("Input angka-1: "))*** — Meminta input angka pertama dari pengguna, langsung dikonversi ke tipe data int.
# 2. ***angka2_2009 = int(input("Input angka-2: "))*** — Meminta input angka kedua dari pengguna, juga dikonversi ke tipe data int.
# 3. ***print("\nNilai awal angka1 =",angka1_2009)*** dan print("Nilai angka2 =",angka2_2009) — Menampilkan nilai awal kedua angka sebagai referensi, agar pengguna bisa membandingkannya dengan hasil setiap operasi assignment di bawah.
# 4. ***hasil_2009 = angka1_2009*** — Menerapkan operator assignment biasa (=): menyalin nilai angka1_2009 ke variabel hasil_2009.
# 5. ***print("\nAssigment biasa (=)")*** dan ***print("Hasil =",hasil_2009)*** — Mencetak label operasi beserta hasilnya, yang nilainya sama persis dengan angka1_2009.
# 6. ***hasil_2009 = angka1_2009*** — Mereset hasil_2009 kembali ke nilai awal angka1_2009, agar operasi berikutnya (+=) dimulai dari nilai yang bersih, bukan hasil operasi sebelumnya.
# 7. ***hasil_2009 += angka2_2009*** — Menerapkan operator assignment penambahan (+=): menambahkan nilai angka2_2009 ke hasil_2009, setara dengan hasil_2009 = hasil_2009 + angka2_2009.
# 8. ***print(...) (2 baris)*** — Mencetak label "Assigment penambahan (+=)" beserta hasilnya.
# 9. ***hasil_2009 = angka1_2009*** — Reset ulang nilai hasil_2009 sebelum operasi pengurangan.
# 10. ***hasil_2009 -= angka2_2009*** — Menerapkan operator assignment pengurangan (-=): mengurangi hasil_2009 dengan angka2_2009, setara hasil_2009 = hasil_2009 - angka2_2009.
# 11. ***print(...) (2 baris)*** — Mencetak label "Assigment pengurangan (-=)" beserta hasilnya.
# 12. ***hasil_2009 = angka1_2009*** — Reset ulang nilai hasil_2009 sebelum operasi perkalian.
# 13. ***hasil_2009 *= angka2_2009*** — Menerapkan operator assignment perkalian (*=): mengalikan hasil_2009 dengan angka2_2009.
# 14. ***print(...) (2 baris)*** — Mencetak label "Assigment perkalian (*=)" beserta hasilnya.
# 15. ***if angka2_2009 != 0:*** — Pengecekan kondisi untuk mencegah error pembagian dengan nol (ZeroDivisionError) sebelum menjalankan tiga operator assignment pembagian di bawahnya.
# 16. ***hasil_2009 = angka1_2009*** lalu hasil_2009 /= angka2_2009 — Menerapkan operator assignment pembagian (/=): hasil hasil_2009 dibagi angka2_2009, hasilnya berupa bilangan desimal (float).
# 17. ***print(...) (2 baris)*** — Mencetak label "Assigment pembagian (/=)" beserta hasilnya.
# 18. ***hasil_2009 = angka1_2009*** lalu ***hasil_2009 //= angka2_2009*** — Menerapkan operator assignment pembagian bulat (//=): hasil pembagian dibulatkan ke bawah (floor division).
# 19. ***print(...) (2 baris)*** — Mencetak label "Assigment pembagian bulat (//=)" beserta hasilnya.
# 20. ***hasil_2009 = angka1_2009*** lalu ***hasil_2009 %= angka2_2009*** — Menerapkan operator assignment sisa bagi (%=): menghasilkan sisa dari pembagian hasil_2009 oleh angka2_2009.
# 21. ***print(...) (2 baris)*** — Mencetak label "Operator sisa bagi (%=)" beserta hasilnya.
# 22. ***else: beserta dua baris print(...) di dalamnya*** — Jika angka2_2009 bernilai 0, program tidak menjalankan operasi pembagian sama sekali dan hanya mencetak pesan peringatan bahwa angka kedua tidak boleh 0.
# 23. ***hasil_2009 = angka1_2009*** — Reset ulang nilai hasil_2009 sebelum operasi pemangkatan (dijalankan di luar blok if/else karena pemangkatan tidak berisiko error meski angka2_2009 bernilai 0).
# 24. ***hasil_2009 **= angka2_2009*** — Menerapkan operator assignment pemangkatan (**=): memangkatkan hasil_2009 dengan angka2_2009, setara hasil_2009 = hasil_2009 ** angka2_2009.
# 25. ***print("\nOperator perpangkatan (**=)") dan print("Hasil =",hasil_2009)*** — Mencetak label operasi pemangkatan beserta hasil akhirnya.

# %% [markdown]
# **Berikut ini adalah Output dari Program Operator Assignment yang dijalankan menggunanakan terminal:**
#
# <div align="center">
# <img src="image/output_assignment.png" width="500"><br>
# <em>Gambar 2.5 : Output Asssignment</em>
# </div>

# %% [markdown]
# ### 2.2.6 Program Operator lainnya "lainnya_2611532009"
# Berikut ini merupakan program lainnya yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan identitas

print("======================================")
print("1. OPERATOR KEANGGOTAAN")
print("======================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_2009 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_2009 = [int(angka.strip()) for angka in input_data_2009.split(',')]

nilai_dicari_2009 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_2009 = nilai_dicari_2009 in data_2009
print("\nOperator keanggotaan IN")
print(nilai_dicari_2009,"in",data_2009,"=",hasil_2009)

# Operator not in
hasil_2009 = nilai_dicari_2009 not in data_2009
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_2009,"not in",data_2009,"=",hasil_2009)

print("======================================")
print("2. OPERATOR IDENTIAS")
print("======================================")

# objek1 menggunakan list dari input perngguna
object1_2009 = data_2009

# objek2 merujuk pada objek yang sama dengan objek1
object2_2009 = object1_2009

# objek3 memiliki isi sama, tetapi merupakan objek baru
object3_2009 = data_2009.copy()
print("object1 =",object1_2009)
print("object2 =",object2_2009)
print("object3 =",object3_2009)

# Operator is
hasil_2009 = object1_2009 is object2_2009
print("\nOperator identitas IS")
print("objek1 is objek2 =",hasil_2009)

# Operator is not
hasil_2009 = object1_2009 is not object2_2009
print("\nOperator identitas IS NOT")
print("objek1 is not objek2 =",hasil_2009)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =",object1_2009 is object3_2009)
print("objek1 == objek3 =",object1_2009 == object3_2009)

# %% [markdown]
# **Penjelasan:**
# 1. ***print("=====...") (3 baris)*** — Mencetak garis pembatas dan judul "1. OPERATOR KEANGGOTAAN" sebagai header visual agar output program lebih mudah dibaca.
#
# 2. ***input_data_2009 = input("Masukkan beberapa angka, pisahkan dengan koma: ")*** — Meminta pengguna memasukkan beberapa angka sekaligus dalam satu baris, dipisahkan tanda koma (misalnya 2, 5, 8, 10). Hasil input masih berupa satu string utuh.
#
# 3. ***data_2009 = [int(angka.strip()) for angka in input_data_2009.split(',')]*** — Bermaksud mengubah string input menjadi list of integer, dengan cara: .split(',') memecah string berdasarkan koma, .strip() menghapus spasi di tiap elemen, lalu int() mengonversinya menjadi angka.
#
# 4. ***nilai_dicari_2009 = int(input("Masukkan angka yang ingin dicari: "))*** — Meminta satu angka dari pengguna sebagai nilai yang akan dicari keberadaannya di dalam data_2009, langsung dikonversi ke int.
#
# 5. ***hasil_2009 = nilai_dicari_2009 in data_2009*** — Menerapkan operator in: mengecek apakah nilai_dicari_2009 ada di dalam list data_2009, hasilnya disimpan sebagai boolean (True/False).
#
# 6. ***print(...) (2 baris setelahnya)*** — Mencetak label "Operator keanggotaan IN" beserta hasil pengecekan tadi.
#
# 7. ***hasil_2009 = nilai_dicari_2009 not in data_2009*** — Menerapkan operator not in: kebalikan dari in, bernilai True jika angka tidak ditemukan dalam list.
#
# 8. ***print(...) (2 baris setelahnya)*** — Mencetak label "Operator keanggotaan NOT IN" beserta hasilnya.
#
# 9. ***print("=====...") (3 baris)*** — Header pembatas untuk bagian "2. OPERATOR IDENTITAS" (di kode asli tertulis "IDENTIAS", ada kesalahan ketik).
#
# 10. ***object1_2009 = data_2009*** — Membuat variabel object1_2009 yang menunjuk ke objek list yang sama dengan data_2009 di memori (bukan menyalin data, hanya membuat referensi baru ke objek yang sudah ada).
#
# 11. ***object2_2009 = object1_2009*** — Membuat object2_2009 yang juga menunjuk ke objek yang sama persis dengan object1_2009 (dan otomatis sama dengan data_2009).
#
# 12. ***object3_2009 = data_2009.copy()*** — Membuat salinan/objek baru dari data_2009 menggunakan method .copy(). Isinya sama, tetapi lokasi memorinya berbeda dari object1_2009/object2_2009.
#
# 13. ***print("object1 =",...), print("object2 =",...), print("object3 =",...)*** — Menampilkan isi ketiga objek untuk memverifikasi bahwa nilainya terlihat identik secara visual, meski identitas objeknya berbeda.
#
# 14. ***hasil_2009 = object1_2009 is object2_2009*** — Menerapkan operator is: mengecek apakah object1_2009 dan object2_2009 adalah objek yang benar-benar sama di memori. Hasilnya True, karena object2_2009 dibuat sebagai referensi langsung ke object1_2009.
#
# 15. ***print(...) (2 baris setelahnya)*** — Mencetak label dan hasil pengecekan is tersebut.
#
# 16. ***hasil_2009 = object1_2009 is not object2_2009*** — Menerapkan operator is not: kebalikan dari is, hasilnya False karena kedua variabel memang objek yang sama.
#
# 17. ***print(...) (2 baris setelahnya)*** — Mencetak label dan hasil pengecekan is not.
#
# 18. ***print("\nPerbandingan identitas dan nilai")*** — Header untuk bagian perbandingan terakhir.
#
# 19. ***print("objek1 is objek3 =",object1_2009 is object3_2009)*** — Membandingkan identitas object1_2009 dan object3_2009. Hasilnya False, karena object3_2009 adalah objek baru hasil .copy(), walau isinya sama.
#
# 20. ***print("objek1 == objek3 =",object1_2009 == object3_2009)*** — Membandingkan nilai/isi object1_2009 dan object3_2009 menggunakan operator ==. Hasilnya True, karena isi kedua list identik, meskipun objeknya berbeda di memori.

# %% [markdown]
# **Berikut ini adalah Output dari Program Operator lainnya yang dijalankan menggunanakan terminal:**
#
# <div align="center">
# <img src="image/output_lainnya.png" width="500"><br>
# <em>Gambar 2.6 : Output lainnya</em>
# </div>

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/Soal_Tugas.png" width="700"><br>
# <em>Gambar 2.7 : Soal_Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "NamaKelas_NIM"

# %%
print("=== SISTEM TRANSAKSI TOKO ===")
print(" ")
nama_2009 = input("Masukkan Nama Pelanggan : ")
status_2009 = input("Masukkan Status Pelanggan (member/nonmember) : ")
total_2009 = int(input("Masukkan Total Belanja : "))
jumlah_2009 = int(input("Masukkan Jumlah Barang : "))
promo_2009 = input("Masukkan Kode Promo : ")

print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan       : {nama_2009}")
print(f"Status Pelanggan     : {status_2009}")
print(f"Total Belanja        : Rp{total_2009}")
print(f"Jumlah Barang        : {jumlah_2009}")
print(f"Kode Promo           : {promo_2009}")

kode_promo_2009 = ["HEMAT10", "HEMAT20", "GRATISONGKIR", "RRQEVOSSAHABATAN"] #list kode promo

syarat_total_2009 = total_2009 >= 200000 # apakah memenuhi syarat belanja
syarat_jumlah_2009 = jumlah_2009 >= 3 # apakah memenuhi syarat barang
status_valid_2009 = status_2009 == "member" # apakah user member
promo_valid_2009 = promo_2009 in kode_promo_2009 # apakah kode promo ada dalam list

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000        : {syarat_total_2009}")
print(f"Jumlah Barang >= 3         : {syarat_jumlah_2009}")
print(f"Status Member              : {status_valid_2009}")
print(f"Kode Promo Tersedia        : {promo_valid_2009}")
print(f"Mendapatkan Diskon         : {syarat_jumlah_2009 or syarat_total_2009}")
print(f"Mendapatkan Promo          : {promo_valid_2009}")

diskon_2009 = 0.05

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                      : Rp{diskon_2009 * total_2009}")
print(f"Total Pembayaran            : Rp{total_2009 - total_2009 * diskon_2009}")
print(f"Rata-rata Harga Barang      : Rp{(total_2009 - total_2009 * diskon_2009)/jumlah_2009}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Hak Akses              : ...")
print(f"Member Access               : {status_valid_2009}")
print(f"Promo Access                : {promo_valid_2009}")
print(f"Free Shipping Access        : ...")

kode_transaksi_2009 = int(status_valid_2009) << 0 | int(syarat_total_2009) << 1 | int(syarat_jumlah_2009) << 2 | int(promo_valid_2009) << 3
kode_referensi_2009 = int(status_valid_2009) << 0 | int(syarat_total_2009) << 1 | int(promo_valid_2009) << 3

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print(f"{format(int(status_valid_2009) << 0,"04b")} | {format(int(syarat_total_2009) << 1,"04b")} | {format(int(syarat_jumlah_2009) << 2,"04b")} | {format(int(promo_valid_2009) << 3,"04b")}")
print(f"Kode Biner   : {format(kode_transaksi_2009,"04b")}")
print(f"Kode Desimal : {kode_transaksi_2009}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(kode_transaksi_2009,"04b")} & {format(int(status_valid_2009) << 0,"04b")}")
print(f"Hasil Biner   : {format((kode_transaksi_2009) & int(status_valid_2009) << 0,"04b")}")
print(f"Hasil Desimal : {(kode_transaksi_2009) & int(status_valid_2009) << 0}")

print("Cek Promo")
print(f"{format(kode_transaksi_2009,"04b")} & {format(int(promo_valid_2009) << 3,"04b")}")
print(f"Hasil Biner   : {format((kode_transaksi_2009) & int(promo_valid_2009) << 3,"04b")}")
print(f"Hasil Desimal : {(kode_transaksi_2009) & int(promo_valid_2009) << 3}")

print("\n=== Perbandingan Status ===")
print(f"Kode Transaksi : {format(kode_transaksi_2009,"04b")}")
print(f"Kode Referensi : {format(kode_referensi_2009,"04b")}")
print(f"{format(kode_transaksi_2009,"04b")} ^ {format(kode_referensi_2009,"04b")}")
print(f"Hasil Biner   : {format((kode_transaksi_2009) ^ (kode_referensi_2009),"04b")}")
print(f"Hasil Desimal : {(kode_transaksi_2009) ^ (kode_referensi_2009)}")

print("\n=== Shift ===")
print(f"{format(kode_transaksi_2009,"04b")} << 1")
print(f"Hasil Biner   : {format((kode_transaksi_2009) << 1,"04b")}")
print(f"Hasil Desimal : {(kode_transaksi_2009) << 1}") 
print("=== SELESAI ===")

# %% [markdown]
# ![output_tugas.png](attachment:output_tugas.png)
#
# **Penjelasan :** Program tugas ini membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.
#
# **Pertanyaan Analisis pada Laporan:**
# 1.     Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.
# 2.     Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.
# 3.     Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.
# 4.     Apa perbedaan antara is dan == pada Python?
# 5.     Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.
# 6.     Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.
# 7.     Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.
#
# **Jawaban:**
# 1. Operator aritmatika
#
# Ada tiga operator aritmatika di kode ini:
#
#      - * pada diskon_2009 * total_2009 menghitung nominal diskon (5% × total belanja).
#      - - pada total_2009 - total_2009 * diskon_2009 menghitung total pembayaran (total belanja dikurangi diskon).
#      - / pada (total_pembayaran) / jumlah_2009 menghitung rata-rata harga per barang. Hasilnya selalu float.
#
# Operator >= termasuk operator perbandingan, dan << termasuk operator bitwise. Keduanya bukan aritmatika.
#
# 2. Perbedaan and, or, not
# or dipakai di kode Anda pada syarat_jumlah_2009 or syarat_total_2009. Hasilnya True jika minimal satu syarat terpenuhi, yaitu belanja ≥ Rp200.000 atau barang ≥ 3.
# and belum dipakai. Hasilnya True hanya jika semua kondisi True. Contohnya status_valid_2009 and promo_valid_2009 berarti pelanggan harus member sekaligus punya kode promo valid.
# not belum dipakai. Operator ini membalik nilai. Contohnya not promo_valid_2009 bernilai True jika kode promo tidak valid.
#
# 3. Operator in dan not in
#
# Kode Anda memakai promo_2009 in kode_promo_2009. Operator ini memeriksa apakah kode yang diketik ada di dalam list ["HEMAT10", "HEMAT20", "GRATISONGKIR", "RRQEVOSSAHABATAN"]. Hasilnya True jika ada dan False jika tidak.
# not in adalah kebalikannya. Contohnya promo_2009 not in kode_promo_2009 bernilai True jika kode tidak terdaftar, sehingga cocok untuk menampilkan pesan "Kode promo tidak valid". Tanpa in, Anda harus menulis empat perbandingan == yang digabung dengan or.
#
# 4. Perbedaan is dan ==
# == membandingkan nilai.
# is membandingkan identitas objek, yaitu apakah keduanya objek yang sama di memori.
#
#
# 5. Operator bitwise untuk hak akses
#
# Kode menyimpan empat status dalam satu bilangan 4 bit:
#
#      1. Bit 0 (nilai 1, biner 0001): Member
#      2. Bit 1 (nilai 2, biner 0010): Belanja ≥ 200.000
#      3. Bit 2 (nilai 4, biner 0100): Barang ≥ 3
#      4. Bit 3 (nilai 8, biner 1000): Promo valid
#
# Operator yang dipakai:
#
#      -<< (shift kiri) menggeser angka 0 atau 1 ke posisi bitnya. Misalnya int(promo_valid_2009) << 3 menghasilkan 8 atau 0.
#      -| (OR) menggabungkan semua bit menjadi kode_transaksi_2009.
#      -& (AND) memeriksa satu hak. kode_transaksi_2009 & 1 bernilai 1 jika pelanggan member, dan kode_transaksi_2009 & 8 bernilai 8 jika promo valid. Hasil 0 berarti hak tidak dimiliki.
#      -^ (XOR) membandingkan kode_transaksi_2009 dengan kode_referensi_2009. Bit yang sama menjadi 0 dan bit yang berbeda menjadi 1. Karena kode referensi tidak menyertakan bit ke-2 (syarat jumlah), hasil XOR bernilai 4 jika jumlah >= 3, selain itu 0.
#      -<< 1 pada kode transaksi menggeser semua bit satu posisi ke kiri, sehingga nilainya menjadi dua kali lipat.
#
# Keunggulannya, empat status tersimpan dalam satu variabel integer dan pengecekannya cukup dengan satu operasi &.
#
# 6. Alur program
#      -Input: nama, status, total belanja (int), jumlah barang (int), dan kode promo dibaca lalu ditampilkan sebagai "DATA TRANSAKSI".
#      -Validasi: empat variabel boolean dibuat, yaitu syarat_total, syarat_jumlah, status_valid (==), dan promo_valid (in), lalu ditampilkan. "Mendapatkan Diskon" dihitung dengan or.
#      -Perhitungan: diskon tetap 5% (0.05), lalu dihitung nominal diskon, total pembayaran, dan rata-rata harga barang.
#      -Hak akses: status member dan promo ditampilkan.
#      -Bitwise: keempat boolean digabung menjadi kode_transaksi_2009, lalu dicek dengan &, dibandingkan dengan ^, dan digeser dengan <<.
#
# 7. Kondisi True dan False
#
# Dengan input contoh di atas:
#
#      -True: status_2009 == "member" karena statusnya member. Selain itu promo_2009 in kode_promo_2009 True karena HEMAT10 ada di list, dan total_2009 >= 200000 True karena 250000 ≥ 200000.
#      -False: jumlah_2009 >= 3 False karena 2 < 3. Jika kode promo diganti ABC123, maka promo_2009 in kode_promo_2009 juga False.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa operator merupakan komponen fundamental dalam bahasa pemrograman Python yang digunakan untuk melakukan berbagai jenis operasi terhadap data, mulai dari perhitungan matematis, pengujian kondisi, penggabungan logika, hingga manipulasi data pada level bit. Melalui keenam program yang telah dibuat (aritmatika, perbandingan, logika, penugasan/assignment, bitwise, serta keanggotaan dan identitas), mahasiswa dapat memahami secara langsung bagaimana setiap kategori operator bekerja dan menghasilkan keluaran yang berbeda-beda sesuai dengan simbol serta aturan yang digunakan.
#
# Dalam konteks pemrograman aritmatika dan penugasan, konsep ini memanfaatkan operator seperti `+`, `-`, `*`, `/`, `//`, `%`, dan `**` untuk melakukan perhitungan dasar, serta bentuk gabungannya (`+=`, `-=`, `*=`, dan seterusnya) sehingga penulisan ekspresi menjadi lebih ringkas tanpa mengubah hasil akhir yang diperoleh. Pada operator perbandingan dan logika, konsep ini memanfaatkan hasil bernilai boolean (`True`/`False`) dari ekspresi relasi (`==`, `!=`, `>`, `<`, dan sejenisnya) yang kemudian dapat digabungkan menggunakan `and`, `or`, dan `not`, sehingga sangat berguna sebagai dasar pengambilan keputusan pada struktur kontrol program. Sementara itu, pada operator bitwise, konsep ini memanfaatkan representasi biner dari suatu bilangan untuk melakukan manipulasi langsung pada bit-bitnya (`&`, `|`, `^`, `~`, `<<`, `>>`), sehingga operasi semacam ini banyak digunakan dalam kasus-kasus yang membutuhkan efisiensi tinggi seperti pengolahan flag, enkripsi sederhana, maupun pemrograman tingkat rendah. Adapun operator keanggotaan dan identitas memanfaatkan pengecekan terhadap isi suatu koleksi data (`in`, `not in`) serta perbedaan antara kesamaan nilai dan kesamaan referensi objek di memori (`is`, `is not`, `==`), sehingga mahasiswa dapat memahami perbedaan mendasar antara membandingkan **nilai** dan membandingkan **identitas objek** dalam Python.
#
# Selain memperoleh pemahaman konseptual, praktikum ini juga melatih mahasiswa dalam menemukan dan memperbaiki kesalahan (debugging) pada program, seperti kesalahan penempatan tanda kurung pada list comprehension, kekeliruan penamaan variabel yang menyebabkan hasil cetak tidak sesuai, hingga kesalahan label pada keluaran program. Dengan demikian, praktikum operator ini tidak hanya memberikan pemahaman teoritis mengenai jenis-jenis operator dalam Python, tetapi juga membekali mahasiswa dengan keterampilan praktis dalam menulis, menguji, dan memperbaiki program secara mandiri sebagai fondasi untuk mempelajari materi pemrograman yang lebih kompleks pada tahap selanjutnya.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Maulana, I., & Sunata, H. (2024). Pengaruh Interaksi Mahasiswa dan Fasilitator... JoiTechs, Vol. 1 No. 2, hlm. 33. https://jurnal.uym.ac.id/index.php/JoiTechs/article/download/466/243
#
# [2] Sugiarto, S., & Lestari. (2022). Pengaruh Sarana Belajar terhadap Hasil Belajar Pemrograman Mahasiswa Kepulauan. Jurnal Pendidikan Tambusai, Vol. 6 No. 3, hlm. 14120–14125. https://jptam.org/index.php/jptam/article/view/5794
#
# [3] Yanti, F., dkk. (2025). Pelatihan Pemrograman Python untuk Mahasiswa PPI UMT. KOMMAS: Jurnal Pengabdian Kepada Masyarakat, Universitas Pamulang. https://openjournal.unpam.ac.id/index.php/kommas/article/view/50477
#
# [4] Modul Pembelajaran: Algoritma Pemrograman, Bagian V, Universitas Tanjungpura, hlm. 20. https://lms.darmajaya.ac.id/mod/resource/view.php?id=294139
#
# [5] Gramedia Literasi. (2023). Pengertian dan Jenis-Jenis Operator dalam Bahasa Pemrograman. https://www.gramedia.com/literasi/?p=45801
